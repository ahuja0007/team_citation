# %%
import ads
import pandas as pd
import cPickle as pickle
import numpy as np
import matplotlib.pyplot as plt
import pylab
import math as math
import scipy.stats as stats
# %matplotlib inline

# %%
# Load in data
filename = 'astro-phstart20000max5000'
pkl_file = open('./results_arxiv_api/' + filename + '.pkl','rb')
arXiv_dict = pickle.load(pkl_file)
# Or, equivalently: 
# arXiv_dict = pickle.load(file('./results_arxiv_api/astro-phstart0max1000.pkl'))

# %%
# def create_df(papers_list):
#     return pd.DataFrame({'Title':[foo.title for foo in papers_list],
#                   'Author':[foo.author for foo in papers_list],
#                   'Citation_count':[foo.citation_count for foo in papers_list],
#                   'Year':[foo.year for foo in papers_list],
#                   'Pub':[foo.pub for foo in papers_list]})

# Parse through comments to extract page and figure numbers.
def search_comments(comments_string,page_numbers=np.NAN,figure_numbers=np.NAN):
    comments = comments_string.split(' ')
    page_number_ind = -1
    figure_number_ind = -1
    for i,com in enumerate(comments):
        if com.find('pages')!=-1:
            page_number_ind = i-1
        if com.find('figures')!=-1:
            figure_number_ind = i-1
    if page_number_ind!=-1:
        if comments[page_number_ind].isdigit():
            page_numbers = int(comments[page_number_ind])
    if figure_number_ind!=-1:
        if comments[figure_number_ind].isdigit():
            figure_numbers = int(comments[figure_number_ind])
        
        
    return [page_numbers,figure_numbers]

# %%
# Function to generate dataframe aggregating all the data

def generate_df(arXiv_dict):
    
    df = pd.DataFrame()

    for i,key in enumerate(arXiv_dict.keys()):
        pages,figures = search_comments(arXiv_dict[key]['comment'])

        try:
            ads_paper = list(ads.query(title=str(arXiv_dict[key]['title'])))
            if len(ads_paper)==1:  
                new_row = pd.DataFrame({'Arxiv_key': [arXiv_dict.keys()[i]], 'Title':[ads_paper[0].title],
                                            'Author':[ads_paper[0].author],
                                            'Citation_count':[ads_paper[0].citation_count],
                                            'Year':[ads_paper[0].year],'Pub':[ads_paper[0].pub],
                                            'Pages':[pages],'Figures':[figures]})
            #         else:
            #             print i,'key',key,'has multiple query returns'
                df = df.append(new_row)
        except:
            continue
            #    except error:
            #       continue

            # Save dataframe (query takes a long time)
    df.to_csv(filename+'.csv', index = False)

    return

# %%
# Actually generate dataframe - do not execute if csv file exists already
generate_df(arXiv_dict)

# %%
# Merge csv files into large dataframe, write to csv
fname1 = 'astro-phstart0max20000.csv'
fname2 = 'astro-phstart20000max5000.csv'
df1 = pd.read_csv(fname1)
df2 = pd.read_csv(fname2)

df = df1.append(df2, ignore_index=True)
df.to_csv('astro-phstart0max25000.csv', index = False)

# %%
# Load data from existing csv
df = pd.read_csv('astro-phstart0max25000.csv')

# %%
# Some exploratory data analysis

# Exclude Citation_count > cutoff
cutoff = 150
cit_xarr = np.arange(0,cutoff)
data = np.array(df.Citation_count[df.Citation_count < cutoff])

# Fit Poisson and Gamma distributions
lambda_MLE = np.mean(data)
poisson_MLE = lambda_MLE**cit_xarr * np.exp(-lambda_MLE) / [math.factorial(item) for item in cit_xarr]
print "Poisson lambda_MLE: ", lambda_MLE
shape, loc, scale = stats.gamma.fit(data)
print "Fitted Gamma shape, loc, scale: ", shape, loc, scale

# Plotting

plt.clf()
plt.hist(data, bins=20, normed=True)
plt.plot(cit_xarr,stats.gamma.pdf(cit_xarr, shape, scale=scale), '-r')
plt.title("Citation count distribution")
plt.xlabel("Normalized citation number")
plt.ylabel("Count")
plt.show()

plt.clf()
plt.plot(cit_xarr, poisson_MLE)
plt.plot(cit_xarr,stats.gamma.pdf(cit_xarr, shape, scale=scale), '-r')
plt.xlabel("Citation count")
plt.ylabel("Probability")
plt.title("Fitted probability distributions")
# Out:
# Poisson lambda_MLE:  28.7565836299
# Fitted Gamma shape, loc, scale:
#  0.527707522935 -5.77574179614e-29 30.7530691395

# %%
# Scatterplots - not very informative

plt.scatter(df.Year.values, df.Citation_count)
plt.axis([1970, 2015, 0, 1000])
plt.xlabel("Year of publication")
plt.ylabel("Citation count")
plt.title('Publication year and citations')
plt.show()

plt.clf()
plt.scatter(df.Figures, df.Citation_count)
plt.axis([0, 30, 0, 250])
plt.xlabel("Number of figures")
plt.ylabel("Citation count")
plt.title('Figures and citations')
plt.show()

plt.scatter(df.Pages, df.Citation_count)
plt.axis([0, 30, 0, 250])
plt.xlabel("Number of pages")
plt.ylabel("Citation count")
plt.title('Pages and citations')
plt.show()

# %%
# Boxplots

#plt.scatter(pub_year, df.Citation_count)

years_of_interest = np.arange(1990,2010)
years_list = []
for i in years_of_interest:
    subdf = df[df.Year.values == i]
    years_list.append(np.array(subdf.Citation_count.values))

figs_list = []
for i in np.arange(1,30):
    subdf = df[df.Figures == i]
    figs_list.append(np.array(subdf.Citation_count.values))

pages_list = []
for i in np.arange(1,30):
    subdf = df[df.Pages == i]
    pages_list.append(np.array(subdf.Citation_count.values))


# Plotting

# fig = plt.figure(figsize=(10,10))
# sct_settings = {'color':'#2ca02c', 'edgecolor':'none', 'alpha':0.6}

box = plt.boxplot(years_list)
plt.axis([0,20,0,250])
pylab.xticks(np.arange(0,20,5), np.arange(0,20,5)+1990)
plt.setp(box['whiskers'], color='black') 
plt.setp(box['boxes'], color='black') 
plt.title('Publication year and citations')
plt.xlabel("Publication year")
plt.ylabel("Number of citations")
plt.show()
    
box = plt.boxplot(figs_list)
plt.axis([0,30,0,250])
pylab.xticks(np.arange(0,30,5), np.arange(0,30,5))
plt.setp(box['whiskers'], color='black') 
plt.setp(box['boxes'], color='black') 
plt.title('Figures and citations')
plt.xlabel("Number of figures")
plt.ylabel("Number of citations")
plt.show()
    
box = plt.boxplot(pages_list)
plt.axis([0,30,0,250])
pylab.xticks(np.arange(0,30,5), np.arange(0,30,5))
plt.setp(box['whiskers'], color='black') 
plt.setp(box['boxes'], color='black') 
plt.title('Pages and citations')
plt.xlabel("Number of pages")
plt.ylabel("Number of citations")
plt.show()

# %% [markdown]
# **Fit Gamma pdfs to various distribution: **
#
# 1) Number of citations for various years of publication
#
# 2) Number of citations for various numbers of figures
#
# 3) Number of citations for various numbers of pages

# %%
# 1) Citation count trends with time?

# Preliminary step: Examining the number of papers per year of publication

plt.clf()
plt.hist(df.Year.values, bins=20)
plt.title("Paper publication year distribution")
plt.xlabel("Publication year")
plt.ylabel("Count")
plt.show()


# Exploratory: the distribution of citation counts for a specific year also looks like an exponential
plt.hist(years_list[5], bins=20) #, normed=True)
#plt.axis([0, 300, 0, 1000])
plt.xlabel("Citation count")
plt.ylabel("Count")
plt.title('Papers and citation counts for a specific year')
plt.show()

# Iterate over the years of publication, fit gamma distribution

good_years = []
shape_list = []
scale_list = []
for i in range(len(years_of_interest)):
    print 'Year: ', years_of_interest[i], '# of papers: ', len(years_list[i])
    if len(years_list[i]) > 100:
        good_years.append(years_of_interest[i])
        shape, loc, scale = stats.gamma.fit(years_list[i])
        print "Fitted Gamma shape, loc, scale: ", shape, loc, scale
        shape_list.append(shape)
        scale_list.append(scale)
        
plt.scatter(good_years, shape_list, c='r')
plt.xlabel("Year")
plt.ylabel("Gamma shape parameter")
plt.title('Citation count Gamma parameter in time')
plt.show()

plt.scatter(good_years, scale_list)
plt.xlabel("Year")
plt.ylabel("Gamma scale parameter")
plt.title('Citation count Gamma parameter in time')
plt.show()
# Out:
# Year:  1990 # of papers:  0
# Year:  1991 # of papers:  3
# Year:  1992 # of papers:  31
# Year:  1993 # of papers:  219
# Fitted Gamma shape, loc, scale:
#  0.537862436131 -7.55564959122e-28 140.189001521
# Year:  1994 # of papers:  525
# Fitted Gamma shape, loc, scale:
#  0.211060272715 -3.98861496069e-27 307.380425183
# Year:  1995 # of papers:  915
# Fitted Gamma shape, loc, scale:
#  0.438217271786 11.0 218.545699966
# Year:  1996 # of papers:  1368
# Fitted Gamma shape, loc, scale:
#  0.145741620759 -3.69676283516e-28 404.256934943
# Year:  1997 # of papers:  2083
# Fitted Gamma shape, loc, scale:
#  0.0129272684555 -6.79496364668e-28 1634.41460249
# Year:  1998 # of papers:  2855
# Fitted Gamma shape, loc, scale:
#  0.00849544041976 -2.95934252395e-27 3023.68946276
# Year:  1999 # of papers:  3595
# Fitted Gamma shape, loc, scale:
#  0.136455342601 -3.10322501915e-27 332.132315692
# Year:  2000 # of papers:  3032
# Fitted Gamma shape, loc, scale:
#  0.07118273632 -4.92206203112e-27 594.320399682
# Year:  2001 # of papers:  319
# Fitted Gamma shape, loc, scale:
#  0.142779242294 -9.09750168821e-28 468.352323542
# Year:  2002 # of papers:  60
# Year:  2003 # of papers:  8
# Year:  2004 # of papers:  5
# Year:  2005 # of papers:  2
# Year:  2006 # of papers:  1
# Year:  2007 # of papers:  1
# Year:  2008 # of papers:  0
# Year:  2009 # of papers:  0

# %%
plt.hist(figs_list[10], bins=20) #, normed=True)
#plt.axis([0, 300, 0, 1000])
plt.xlabel("Citation count")
plt.ylabel("Count")
plt.title('Papers and citation counts for specific figure number')
plt.show()

good_figs = []
shape_list = []
scale_list = []
for i in range(len(figs_list)):
    print 'Figure number: ', i, '# of papers: ', len(figs_list[i])
    if len(figs_list[i]) > 100:
        good_figs.append(i)
        shape, loc, scale = stats.gamma.fit(figs_list[i])
        print "Fitted Gamma shape, loc, scale: ", shape, loc, scale
        shape_list.append(shape)
        scale_list.append(scale)

plt.scatter(good_figs, shape_list, c='r')
plt.xlabel("Number of figures")
plt.ylabel("Gamma shape parameter")
plt.title('Citation count Gamma parameter relation to figure number')
plt.show()

plt.scatter(good_figs, scale_list)
plt.xlabel("Number of figures")
plt.ylabel("Gamma scale parameter")
plt.title('Citation count Gamma parameter relation to figure number')
plt.show()
# Out:
# Figure number:  0 # of papers:  10
# Figure number:  1 # of papers:  920
# Fitted Gamma shape, loc, scale:
#  0.345810919969 13.0 293.700599573
# Figure number:  2 # of papers:  815
# Fitted Gamma shape, loc, scale:
#  0.102888258257 15.0 230.543647565
# Figure number:  3 # of papers:  727
# Fitted Gamma shape, loc, scale:
#  0.09464034762 -6.84734549329e-27 393.537832166
# Figure number:  4 # of papers:  533
# Fitted Gamma shape, loc, scale:
#  0.353732389695 9.0 93.4793470999
# Figure number:  5 # of papers:  455
# Fitted Gamma shape, loc, scale:
#  0.0677320967781 -2.12777201499e-26 578.735234369
# Figure number:  6 # of papers:  364
# Fitted Gamma shape, loc, scale:
#  0.0355466270901 -1.30467370468e-26 1039.85865821
# Figure number:  7 # of papers:  339
# Fitted Gamma shape, loc, scale:
#  0.183001223791 -4.67368848355e-27 295.907380295
# Figure number:  8 # of papers:  284
# Fitted Gamma shape, loc, scale:
#  0.0334295942957 -3.34203838106e-27 1529.77714484
# Figure number:  9 # of papers:  234
# Fitted Gamma shape, loc, scale:
#  0.520065221733 -1.36217587594e-26 175.73116346
# Figure number:  10 # of papers:  174
# Fitted Gamma shape, loc, scale:
#  0.105679589949 -1.34700400482e-27 643.474276726
# Figure number:  11 # of papers:  151
# Fitted Gamma shape, loc, scale:
#  0.261268341259 -3.86923413727e-29 233.1902154
# Figure number:  12 # of papers:  150
# Fitted Gamma shape, loc, scale:
#  0.399379608731 11.0 400.522227665
# Figure number:  13 # of papers:  126
# Fitted Gamma shape, loc, scale:
#  0.760241742028 26.0 110.807617174
# Figure number:  14 # of papers:  95
# Figure number:  15 # of papers:  68
# Figure number:  16 # of papers:  58
# Figure number:  17 # of papers:  47
# Figure number:  18 # of papers:  31
# Figure number:  19 # of papers:  26
# Figure number:  20 # of papers:  24
# Figure number:  21 # of papers:  20
# Figure number:  22 # of papers:  19
# Figure number:  23 # of papers:  14
# Figure number:  24 # of papers:  9
# Figure number:  25 # of papers:  8
# Figure number:  26 # of papers:  5
# Figure number:  27 # of papers:  3
# Figure number:  28 # of papers:  1

# %%
plt.hist(pages_list[10], bins=20) #, normed=True)
#plt.axis([0, 300, 0, 1000])
plt.xlabel("Citation count")
plt.ylabel("Count")
plt.title('Papers and citation counts for specific page number')
plt.show()

good_pages = []
shape_list = []
scale_list = []
for i in range(len(pages_list)):
    print 'Pages number: ', i, '# of papers: ', len(pages_list[i])
    if len(pages_list[i]) > 100:
        good_pages.append(i)
        shape, loc, scale = stats.gamma.fit(pages_list[i])
        print "Fitted Gamma shape, loc, scale: ", shape, loc, scale
        shape_list.append(shape)
        scale_list.append(scale)

plt.scatter(good_pages, shape_list, c='r')
plt.xlabel("Number of pages")
plt.ylabel("Gamma shape parameter")
plt.title('Citation count Gamma parameter relation to pages number')
plt.show()

plt.scatter(good_pages, scale_list)
plt.xlabel("Number of pages")
plt.ylabel("Gamma scale parameter")
plt.title('Citation count Gamma parameter relation to pages number')
plt.show()
# Out:
# Pages number:  0 # of papers:  0
# Pages number:  1 # of papers:  173
# Fitted Gamma shape, loc, scale:
#  0.208872561157 -2.49791030242e-30 43.3071995684
# Pages number:  2 # of papers:  196
# Fitted Gamma shape, loc, scale:
#  0.250472130139 -5.6925029068e-29 96.2231952666
# Pages number:  3 # of papers:  1109
# Fitted Gamma shape, loc, scale:
#  0.235432991301 13.0 118.147882474
# Pages number:  4 # of papers:  703
# Fitted Gamma shape, loc, scale:
#  0.0836109285156 10.0 269.469308548
# Pages number:  5 # of papers:  676
# Fitted Gamma shape, loc, scale:
#  0.129378652692 8.0 133.778018955
# Pages number:  6 # of papers:  566
# Fitted Gamma shape, loc, scale:
#  0.52706258995 13.0 120.058313433
# Pages number:  7 # of papers:  807
# Fitted Gamma shape, loc, scale:
#  0.0334287796915 15.0 436.490728064
# Pages number:  8 # of papers:  590
# Fitted Gamma shape, loc, scale:
#  0.277129093771 10.0 94.4771620607
# Pages number:  9 # of papers:  805
# Fitted Gamma shape, loc, scale:
#  0.569746805622 11.0 95.5880622401
# Pages number:  10 # of papers:  605
# Fitted Gamma shape, loc, scale:
#  0.726615988261 6.0 56.9707487267
# Pages number:  11 # of papers:  611
# Fitted Gamma shape, loc, scale:
#  0.0746518235654 18.0 326.147699573
# Pages number:  12 # of papers:  521
# Fitted Gamma shape, loc, scale:
#  0.0606303804176 -4.96841747834e-27 538.244790311
# Pages number:  13 # of papers:  512
# Fitted Gamma shape, loc, scale:
#  0.300021955188 -6.59307095767e-28 147.732318526
# Pages number:  14 # of papers:  436
# Fitted Gamma shape, loc, scale:
#  0.0811905923935 -2.35857269163e-27 590.000122329
# Pages number:  15 # of papers:  384
# Fitted Gamma shape, loc, scale:
#  0.355298518925 8.0 113.627459013
# Pages number:  16 # of papers:  312
# Fitted Gamma shape, loc, scale:
#  0.612247375359 11.0 77.6981647251
# Pages number:  17 # of papers:  350
# Fitted Gamma shape, loc, scale:
#  0.416600955525 11.0 212.021868799
# Pages number:  18 # of papers:  276
# Fitted Gamma shape, loc, scale:
#  0.35161353899 -6.87308771036e-27 218.390176374
# Pages number:  19 # of papers:  272
# Fitted Gamma shape, loc, scale:
#  0.300913942849 -1.45672728306e-27 247.192995393
# Pages number:  20 # of papers:  225
# Fitted Gamma shape, loc, scale:
#  0.100432141813 -4.75605191155e-27 630.930004795
# Pages number:  21 # of papers:  206
# Fitted Gamma shape, loc, scale:
#  0.271586676502 -2.79418558031e-27 227.344052421
# Pages number:  22 # of papers:  217
# Fitted Gamma shape, loc, scale:
#  0.064738546337 35.0 892.116361339
# Pages number:  23 # of papers:  170
# Fitted Gamma shape, loc, scale:
#  0.348555623913 -1.84573495058e-29 205.101127724
# Pages number:  24 # of papers:  151
# Fitted Gamma shape, loc, scale:
#  0.679433931515 5.0 107.634274185
# Pages number:  25 # of papers:  138
# Fitted Gamma shape, loc, scale:
#  0.769167940729 18.0 106.54289036
# Pages number:  26 # of papers:  151
# Fitted Gamma shape, loc, scale:
#  0.0821035264621 -5.69936439818e-26 877.356708979
# Pages number:  27 # of papers:  126
# Fitted Gamma shape, loc, scale:
#  0.208720578528 -2.02276822892e-25 286.299811965
# Pages number:  28 # of papers:  116
# Fitted Gamma shape, loc, scale:
#  0.407909486514 16.0 142.066467669

# %%
df
# Out:
#                                      Arxiv_key  \
# 0      http://arxiv.org/abs/astro-ph/9504075v1
# 1        http://arxiv.org/abs/hep-ph/9306247v1
# 2      http://arxiv.org/abs/astro-ph/9305017v1
# 3      http://arxiv.org/abs/astro-ph/9406070v1
# 4      http://arxiv.org/abs/astro-ph/9509101v1
# 5      http://arxiv.org/abs/astro-ph/9409048v1
# 6      http://arxiv.org/abs/astro-ph/9410019v1
# 7      http://arxiv.org/abs/astro-ph/9505014v2
# 8      http://arxiv.org/abs/astro-ph/9511121v1
# 9      http://arxiv.org/abs/astro-ph/9506135v1
# 10     http://arxiv.org/abs/astro-ph/9512159v1
# 11     http://arxiv.org/abs/astro-ph/9401020v1
# 12     http://arxiv.org/abs/astro-ph/9510082v1
# 13     http://arxiv.org/abs/astro-ph/9509103v1
# 14     http://arxiv.org/abs/astro-ph/9503109v1
# 15        http://arxiv.org/abs/gr-qc/9309021v1
# 16     http://arxiv.org/abs/astro-ph/9506123v1
# 17     http://arxiv.org/abs/astro-ph/9410064v1
# 18     http://arxiv.org/abs/astro-ph/9311012v1
# 19       http://arxiv.org/abs/hep-ph/9403259v1
# 20     http://arxiv.org/abs/astro-ph/9509119v1
# 21     http://arxiv.org/abs/astro-ph/9404008v1
# 22     http://arxiv.org/abs/astro-ph/9308047v1
# 23       http://arxiv.org/abs/hep-th/9408023v1
# 24     http://arxiv.org/abs/astro-ph/9504098v1
# 25     http://arxiv.org/abs/astro-ph/9305011v1
# 26     http://arxiv.org/abs/astro-ph/9509148v1
# 27     http://arxiv.org/abs/astro-ph/9508054v2
# 28     http://arxiv.org/abs/astro-ph/9309039v1
# 29     http://arxiv.org/abs/astro-ph/9606066v2
# ...                                        ...
# 14998  http://arxiv.org/abs/astro-ph/9910467v1
# 14999  http://arxiv.org/abs/astro-ph/0002494v1
# 15000  http://arxiv.org/abs/astro-ph/0004112v2
# 15001  http://arxiv.org/abs/astro-ph/0001283v1
# 15002  http://arxiv.org/abs/astro-ph/9911348v1
# 15003  http://arxiv.org/abs/astro-ph/0004388v1
# 15004  http://arxiv.org/abs/astro-ph/9911460v1
# 15005  http://arxiv.org/abs/astro-ph/0003313v1
# 15006  http://arxiv.org/abs/astro-ph/0003194v2
# 15007  http://arxiv.org/abs/astro-ph/9911296v1
# 15008  http://arxiv.org/abs/astro-ph/9910280v3
# 15009    http://arxiv.org/abs/hep-ph/0003298v1
# 15010  http://arxiv.org/abs/astro-ph/0005544v2
# 15011     http://arxiv.org/abs/gr-qc/0003063v1
# 15012  http://arxiv.org/abs/astro-ph/9911466v1
# 15013  http://arxiv.org/abs/astro-ph/9912208v1
# 15014  http://arxiv.org/abs/astro-ph/0002031v3
# 15015  http://arxiv.org/abs/astro-ph/9911036v1
# 15016  http://arxiv.org/abs/astro-ph/0001108v1
# 15017  http://arxiv.org/abs/astro-ph/0005527v1
# 15018  http://arxiv.org/abs/astro-ph/9910531v1
# 15019  http://arxiv.org/abs/astro-ph/0004392v1
# 15020   http://arxiv.org/abs/physics/9912033v1
# 15021  http://arxiv.org/abs/astro-ph/9912243v1
# 15022     http://arxiv.org/abs/gr-qc/0005114v2
# 15023    http://arxiv.org/abs/hep-ph/0005217v2
# 15024  http://arxiv.org/abs/astro-ph/9912159v1
# 15025   http://arxiv.org/abs/physics/0004068v1
# 15026  http://arxiv.org/abs/astro-ph/0003190v2
# 15027  http://arxiv.org/abs/astro-ph/0001509v1
#
#                                                   Author  Citation_count  \
# 0      [u'Fenimore, E. E.', u"in 't Zand, J. J. M.", ...             190
# 1                               [u'Krauss, Lawrence M.']               0
# 2      [u'Zaggia, S. R.', u'Capaccioli, M.', u'Piotto...              16
# 3                    [u'Pijpers, F. P.', u'Wanders, I.']              26
# 4           [u'van Kerkwijk, M. H.', u'Kulkarni, S. R.']              23
# 5                                    [u'Pijpers, F. P.']               8
# 6         [u'Borra, E. F.', u'Moretto, G.', u'Wang, M.']               3
# 7                                  [u'Soares, D. S. L.']               3
# 8                               [u'Weinberg, Martin D.']              20
# 9                                 [u'Harding, Alice K.']               6
# 10     [u'di Clemente, A.', u'Giallongo, E.', u'Natal...              65
# 11                      [u'Maoz, Dan', u'Gould, Andrew']              40
# 12          [u'Gunn, Katherine F.', u'Thomas, Peter A.']              29
# 13              [u'Pych, Wojciech', u'Olech, Arkadiusz']              12
# 14     [u'de Propris, Roberto', u'Pritchet, Christoph...              84
# 15                                  [u'Fakir, Redouane']               2
# 16     [u'Hau, G. K. T.', u'Ferguson, H. C.', u'Lahav...              18
# 17                                         [u'Ojha, D.']               0
# 18     [u'Chiba, Takashi', u'Sugiyama, Naoshi', u'Sut...              15
# 19     [u'Davidson, Sacha', u'Murayama, Hitoshi', u'O...              15
# 20                            [u'van den Bergh, Sidney']              22
# 21                                       [u'Page, Dany']              42
# 22     [u'Martin, E. L.', u'Rebolo, R.', u'Magazzu, A...             125
# 23        [u'Garc\xeda-Bellido, Juan', u'Linde, Andrei']             101
# 24                                    [u'Giampieri, G.']               0
# 25                                   [u'Primack, J. R.']              11
# 26     [u'Lubin, Lori M.', u'Cen, Renyue', u'Bahcall,...              50
# 27     [u'Sellgren, K.', u'Werner, M. W.', u'Allamand...              32
# 28     [u'Lucchin, F.', u'Matarrese, S.', u'Moscardin...               0
# 29                                      [u'Knox, Lloyd']              16
# ...                                                  ...             ...
# 14998  [u'Pell\xf3, R.', u'Bolzonella, M.', u'Campusa...               4
# 14999                 [u'Mobasher, B.', u'James, P. A.']              12
# 15000        [u'Koopmans, L. V. E.', u'de Bruyn, A. G.']              63
# 15001       [u'Milgrom, Mordehai', u'Usov, Vladimir V.']               4
# 15002  [u'Hearnshaw, J. B.', u'Bond, I. A.', u'Ratten...               4
# 15003                 [u'Gardiner, T. A.', u'Frank, A.']              13
# 15004       [u'Tittley, Eric R.', u'Couchman, H. M. P.']               5
# 15005             [u'Ardila, David R.', u'Basri, Gibor']              29
# 15006             [u'Binney, J. J.', u'Sellwood, J. A.']               3
# 15007  [u'Tammann, G. A.', u'Parodi, B. R.', u'Reindl...               3
# 15008     [u'Sazonov, Sergei Y.', u'Sunyaev, Rashid A.']              30
# 15009            [u'Martins, C. J.', u'Shellard, E. P.']              95
# 15010  [u'Catelan, Paolo', u'Porciani, Cristiano', u'...              17
# 15011             [u'Bernui, A.', u'Teixeira, A. F. F.']               3
# 15012                                 [u'Murray, J. R.']              50
# 15013  [u'Xanthopoulos', u'Jackson, N. J.', u'Snellen...               0
# 15014                       [u'Abel, T.', u'Haiman, Z.']               9
# 15015  [u'Ott, T.', u'Hackenberg, W.', u'Rabien, S.',...               4
# 15016        [u'Koopmans, L. V. E.', u'de Bruyn, A. G.']               5
# 15017      [u'Stanghellini, Letizia', u'Renzini, Alvio']              25
# 15018  [u'Douvion, T.', u'Lagage, P. O.', u'Cesarsky,...              31
# 15019                           [u'Matsubara, Takahiko']              26
# 15020                             [u'Schwarzschild, K.']              27
# 15021  [u'Sandquist, Eric L.', u'Taam, Ronald E.', u'...              54
# 15022  [u'Harada, Tomohiro', u'Iguchi, Hideo', u'Naka...              23
# 15023  [u'Rybczy\u0144ski, M.', u'Wodarczyk, Z.', u'W...               6
# 15024  [u'Pestalozzi, M. R.', u'Benz, A. O.', u'Conwa...              15
# 15025  [u'Varshalovich, D. A.', u'Potekhin, A. Y.', u...               5
# 15026  [u'Fowler, J. W.', u'Fortson, L. F.', u'Jui, C...             105
# 15027  [u'Gallant, Yves A.', u'Achterberg, Abraham', ...               9
#
#        Figures  Pages                                                Pub  \
# 0          NaN     19                          The Astrophysical Journal
# 1          NaN     16                                     ArXiv e-prints
# 2            8      6                         Astronomy and Astrophysics
# 3          NaN     16  Monthly Notices of the Royal Astronomical Society
# 4          NaN      6                          The Astrophysical Journal
# 5          NaN     11                         Astronomy and Astrophysics
# 6          NaN      8       Astronomy and Astrophysics Supplement Series
# 7          NaN    NaN                         Astronomy and Astrophysics
# 8          NaN     19                          The Astrophysical Journal
# 9          NaN      5                        High Velocity Neutron Stars
# 10         NaN     23                          The Astrophysical Journal
# 11         NaN     16                          The Astrophysical Journal
# 12           2    NaN  Monthly Notices of the Royal Astronomical Society
# 13         NaN     15                                   Acta Astronomica
# 14           2     15                          The Astrophysical Journal
# 15         NaN    NaN  ArXiv General Relativity and Quantum Cosmology...
# 16         NaN    NaN  Monthly Notices of the Royal Astronomical Society
# 17         NaN      5                     The Formation of the Milky Way
# 18         NaN    NaN                          The Astrophysical Journal
# 19         NaN     10                                  Physics Letters B
# 20           2     21                           The Astronomical Journal
# 21         NaN     26                          The Astrophysical Journal
# 22         NaN    NaN                         Astronomy and Astrophysics
# 23         NaN     30                                  Physical Review D
# 24           7     15       General Relativity and Gravitational Physics
# 25         NaN    NaN                    Critical Dialogues in Cosmology
# 26         NaN     17                          The Astrophysical Journal
# 27         NaN     38        The Astrophysical Journal Supplement Series
# 28         NaN      8                                     ArXiv e-prints
# 29           3     15                          The Astrophysical Journal
# ...        ...    ...                                                ...
# 14998        3      5          Astrophysics and Space Science Supplement
# 14999        7     17  Monthly Notices of the Royal Astronomical Society
# 15000       11     21                         Astronomy and Astrophysics
# 15001      NaN     10                          The Astrophysical Journal
# 15002        3    NaN  IAU Colloq. 176: The Impact of Large-Scale Sur...
# 15003        3      8                          The Astrophysical Journal
# 15004        2     13  Monthly Notices of the Royal Astronomical Society
# 15005       11     34                          The Astrophysical Journal
# 15006      NaN    NaN                                     ArXiv e-prints
# 15007        2     12  IAU Colloq. 176: The Impact of Large-Scale Sur...
# 15008       17     29                          The Astrophysical Journal
# 15009        6     16                                  Physical Review D
# 15010      NaN      6  Monthly Notices of the Royal Astronomical Society
# 15011      NaN     14  ArXiv General Relativity and Quantum Cosmology...
# 15012      NaN      6  Monthly Notices of the Royal Astronomical Society
# 15013      NaN      5                                     ArXiv e-prints
# 15014      NaN      9                        Molecular Hydrogen in Space
# 15015      NaN    NaN                             Experimental Astronomy
# 15016        5      8  Perspectives on Radio Astronomy: Science with ...
# 15017       27    NaN                          The Astrophysical Journal
# 15018        2      5                         Astronomy and Astrophysics
# 15019      NaN     10                          The Astrophysical Journal
# 15020      NaN      9                                     ArXiv e-prints
# 15021       10     28                          The Astrophysical Journal
# 15022      NaN     34                                  Physical Review D
# 15023      NaN      4          Nuclear Physics B Proceedings Supplements
# 15024        5      6                         Astronomy and Astrophysics
# 15025      NaN      6                                     ArXiv e-prints
# 15026       10     25                              Astroparticle Physics
# 15027        2      6         Gamma-ray Bursts, 5th Huntsville Symposium
#
#                                                    Title  Year
# 0      [u'Gamma-Ray Burst Peak Duration as a Function...  1995
# 1      [u'The Impact of COBE on Inflation, Dark Matte...  1993
# 2      [u'High resolution kinematics of galactic glob...  1993
# 3      [u'Reverberation mapping of active galactic nu...  1994
# 4      [u'Spectroscopy of the White Dwarf Companions ...  1995
# 5      [u'On the propagation of sound waves in a stel...  1995
# 6      [u'An optical corrector design that allows a f...  1995
# 7      [u'Binary galaxies and alternative physics. I....  1996
# 8      [u'High-Accuracy Minimum Relaxation N-Body Sim...  1996
# 9      [u'The nature of plerions surrounding soft gam...  1996
# 10     [u'The Variability of Quasars. II. Frequency D...  1996
# 11     [u'A Spectroscopic Method to Measure MACHO Pro...  1994
# 12     [u'The Baryon Catastrophe and the multiphase i...  1996
# 13     [u'CCD Photometry of Dwarf Nova AL COM in Supe...  1995
# 14     [u'Evidence for Steep Luminosity Functions in ...  1995
# 15          [u'Early Direct Detection of Gravity Waves']  1993
# 16     [u'Visual search for galaxies near the norther...  1995
# 17     [u'Kinematical properties of the thick disk of...  1995
# 18     [u'Microwave Background Anisotropies in Primev...  1994
# 19     [u'On preserving a B + L asymmetry produced in...  1994
# 20     [u'Some Constraints on Galaxy Evolution Impose...  1995
# 21       [u'Geminga: A Cooling Superfluid Neutron Star']  1994
# 22     [u'Pre-main sequence lithium burning. I. Weak ...  1994
# 23     [u'Stationarity of inflation and predictions o...  1995
# 24       [u'Relativity Experiments in the Solar System']  1996
# 25     [u'The best Theory of Cosmic Structure Formati...  1997
# 26     [u'The Baryon Fraction and Velocity-Temperatur...  1996
# 27     [u'A Survey of Near-Infrared Emission in Visua...  1996
# 28     [u'Galaxy Velocity Field in Tilted Cold Dark M...  1993
# 29     [u'Cosmic Microwave Background Anisotropy Obse...  1997
# ...                                                  ...   ...
# 14998  [u'Properties of high-z galaxies seen through ...  2001
# 14999  [u'Spectroscopic constraints on the stellar po...  2000
# 15000  [u'Microlensing of multiply-imaged compact rad...  2000
# 15001  [u'Induction of Supernova-like Explosions by G...  2000
# 15002  [u'Photometry of Pulsating Stars in the Magell...  2000
# 15003  [u'The Magnetic Geometry of Pulsed Astrophysic...  2000
# 15004  [u'Hierarchical clustering and the baryon dist...  2000
# 15005       [u'The Balmer Wavelength Range of BP Tauri']  2000
# 15006  [u'Disk heating and stellar migration in galax...  2000
# 15007              [u'The Status of the Distance Scale']  2000
# 15008  [u'The Profile of a Narrow Line after Single S...  2000
# 15009  [u'Extending the velocity-dependent one-scale ...  2002
# 15010          [u'Two ways of biasing galaxy formation']  2000
# 15011  [u'Cosmic crystallography: the euclidean isome...  2000
# 15012  [u'The precession of eccentric discs in close ...  2000
# 15013               [u'The CERES Astronomical Database']  1999
# 15014  [u'The Role of H<SUB>2</SUB> Molecules in Cosm...  2000
# 15015  [u'The ALFA Laser: Beam Relay and Control Syst...  2000
# 15016  [u'Micro & Strong Lensing with the Square Kilo...  2000
# 15017  [u'Synthetic Post-Asymptotic Giant Branch Evol...  2000
# 15018  [u'Element mixing in the Cassiopeia A supernova']  1999
# 15019  [u'The Gravitational Lensing in Redshift-Space...  2000
# 15020  [u"On the gravitational field of a sphere of i...  1999
# 15021  [u'On the Formation of Helium Double Degenerat...  2000
# 15022  [u'Power, energy, and spectrum of a naked sing...  2000
# 15023                        [u'Muons from strangelets']  2001
# 15024  [u'VLBI observations of two single dMe stars: ...  2000
# 15025  [u'Puzzle of the constancy of fundamental cons...  2000
# 15026  [u'A measurement of the cosmic ray spectrum an...  2001
# 15027  [u'Particle acceleration at ultra-relativistic...  2000
#
# [15028 rows x 8 columns]
