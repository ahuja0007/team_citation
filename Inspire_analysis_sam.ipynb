# %%
# %matplotlib inline 

import numpy as np
import pickle
import pandas as pd
from glob import glob
import matplotlib.pyplot as plt
import random
import datetime as dt
import json
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn import cross_validation
from itertools import *
import random

# %%
## load dataframe from the inspire data augmented with additional features
inspire_data=pd.DataFrame.from_csv('INSPIRE_merged_data.csv')
inspire_data.head()
# Out:
#                                                                                     Author  \
# Arxiv_key
# http://arxiv.org/abs/astro-ph/9504075v1  [u'Fenimore, E. E.', u"in 't Zand, J. J. M.", ...
# http://arxiv.org/abs/hep-ph/9306247v1                             [u'Krauss, Lawrence M.']
# http://arxiv.org/abs/astro-ph/9305017v1  [u'Zaggia, S. R.', u'Capaccioli, M.', u'Piotto...
# http://arxiv.org/abs/astro-ph/9406070v1                [u'Pijpers, F. P.', u'Wanders, I.']
# http://arxiv.org/abs/astro-ph/9509101v1       [u'van Kerkwijk, M. H.', u'Kulkarni, S. R.']
#
#                                          Citation_count  Figures  Pages  \
# Arxiv_key
# http://arxiv.org/abs/astro-ph/9504075v1             190      NaN     19
# http://arxiv.org/abs/hep-ph/9306247v1                 0      NaN     16
# http://arxiv.org/abs/astro-ph/9305017v1              16        8      6
# http://arxiv.org/abs/astro-ph/9406070v1              26      NaN     16
# http://arxiv.org/abs/astro-ph/9509101v1              23      NaN      6
#
#                                                                                        Pub  \
# Arxiv_key
# http://arxiv.org/abs/astro-ph/9504075v1                          The Astrophysical Journal
# http://arxiv.org/abs/hep-ph/9306247v1                                       ArXiv e-prints
# http://arxiv.org/abs/astro-ph/9305017v1                         Astronomy and Astrophysics
# http://arxiv.org/abs/astro-ph/9406070v1  Monthly Notices of the Royal Astronomical Society
# http://arxiv.org/abs/astro-ph/9509101v1                          The Astrophysical Journal
#
#                                                                                      Title  \
# Arxiv_key
# http://arxiv.org/abs/astro-ph/9504075v1  [u'Gamma-Ray Burst Peak Duration as a Function...
# http://arxiv.org/abs/hep-ph/9306247v1    [u'The Impact of COBE on Inflation, Dark Matte...
# http://arxiv.org/abs/astro-ph/9305017v1  [u'High resolution kinematics of galactic glob...
# http://arxiv.org/abs/astro-ph/9406070v1  [u'Reverberation mapping of active galactic nu...
# http://arxiv.org/abs/astro-ph/9509101v1  [u'Spectroscopy of the White Dwarf Companions ...
#
#                                          Year  Pub_cit_median  Avg_Cens  \
# Arxiv_key
# http://arxiv.org/abs/astro-ph/9504075v1  1995              41  0.000795
# http://arxiv.org/abs/hep-ph/9306247v1    1993               1  0.002003
# http://arxiv.org/abs/astro-ph/9305017v1  1993              27  0.000266
# http://arxiv.org/abs/astro-ph/9406070v1  1994              32  0.000030
# http://arxiv.org/abs/astro-ph/9509101v1  1995              41  0.003102
#
#                                            Avg_Cols    Avg_Pubs  Max_Cens  \
# Arxiv_key
# http://arxiv.org/abs/astro-ph/9504075v1  248.200000   88.800000  0.001620
# http://arxiv.org/abs/hep-ph/9306247v1    113.000000  132.000000  0.002003
# http://arxiv.org/abs/astro-ph/9305017v1  247.666667  113.333333  0.000383
# http://arxiv.org/abs/astro-ph/9406070v1   60.500000    9.000000  0.000033
# http://arxiv.org/abs/astro-ph/9509101v1  678.000000  243.500000  0.004376
#
#                                          Max_Cols  Max_Pubs  Min_Cens  \
# Arxiv_key
# http://arxiv.org/abs/astro-ph/9504075v1       548       163  0.000268
# http://arxiv.org/abs/hep-ph/9306247v1         113       132  0.002003
# http://arxiv.org/abs/astro-ph/9305017v1       294       169  0.000192
# http://arxiv.org/abs/astro-ph/9406070v1        80        13  0.000027
# http://arxiv.org/abs/astro-ph/9509101v1      1128       374  0.001828
#
#                                          Min_Cols  Min_Pubs
# Arxiv_key
# http://arxiv.org/abs/astro-ph/9504075v1        40        31
# http://arxiv.org/abs/hep-ph/9306247v1         113       132
# http://arxiv.org/abs/astro-ph/9305017v1       207        65
# http://arxiv.org/abs/astro-ph/9406070v1        41         5
# http://arxiv.org/abs/astro-ph/9509101v1       228       113

# %%
## add more features calculated from ADS
good_df=pd.DataFrame.from_csv('good_df3.csv')
inspire_data=inspire_data.merge(good_df[['Arxiv_key','h_index','m_index','e_index','i10_index','g_index','tori_index','riq_index']],right_on=['Arxiv_key'],left_index=True)
inspire_data.head()
# Out:
#                                               Author  Citation_count  Figures  \
# 0  [u'Zaggia, S. R.', u'Capaccioli, M.', u'Piotto...              16        8
# 1  [u'de Propris, Roberto', u'Pritchet, Christoph...              84        2
# 2                         [u'van den Bergh, Sidney']              22        2
# 3                                   [u'Knox, Lloyd']              16        3
# 4  [u'Jedamzik, Karsten', u'Mathews, Grant J.', u...              12        2
#
#    Pages                         Pub  \
# 0      6  Astronomy and Astrophysics
# 1     15   The Astrophysical Journal
# 2     21    The Astronomical Journal
# 3     15   The Astrophysical Journal
# 4     13   The Astrophysical Journal
#
#                                                Title  Year  Pub_cit_median  \
# 0  [u'High resolution kinematics of galactic glob...  1993              27
# 1  [u'Evidence for Steep Luminosity Functions in ...  1995              41
# 2  [u'Some Constraints on Galaxy Evolution Impose...  1995              43
# 3  [u'Cosmic Microwave Background Anisotropy Obse...  1997              41
# 4  [u'Absence of a Lower Limit on Omega B in Inho...  1995              41
#
#    Avg_Cens    Avg_Cols     ...      Min_Cols  Min_Pubs  \
# 0  0.000266  247.666667     ...           207        65
# 1  0.000430  129.250000     ...            22         6
# 2  0.000881   83.000000     ...            83        31
# 3  0.001094  185.000000     ...           185        84
# 4  0.002299  263.000000     ...            61        51
#
#                                  Arxiv_key  h_index  m_index  e_index  \
# 0  http://arxiv.org/abs/astro-ph/9305017v1        3      1.5      5.7
# 1  http://arxiv.org/abs/astro-ph/9503109v1        2      0.7     10.8
# 2  http://arxiv.org/abs/astro-ph/9509119v1       10      5.0     14.0
# 3  http://arxiv.org/abs/astro-ph/9606066v2        6      0.5     21.0
# 4  http://arxiv.org/abs/astro-ph/9407035v1        4      1.3     11.7
#
#    i10_index g_index  tori_index  riq_index
# 0          2       5         0.3        293
# 1          2       3         0.8        303
# 2         11      18         8.0       1413
# 3          4      11        13.1        278
# 4          4       5         1.7        438
#
# [5 rows x 25 columns]

# %%
##count the number of authors per paper
inspire_data['author_counts']=map(lambda x: len(x.strip('[]').split(','))*1.0/2,inspire_data['Author'])

## Take the features we are interested in
numeric_components=inspire_data[['Figures','Pages','Year','Pub_cit_median','Avg_Cens','Avg_Cols','Avg_Pubs','Max_Cens','Max_Cols','Max_Pubs','Min_Cens','Min_Cols','Min_Pubs','author_counts','Citation_count','h_index','m_index','e_index','i10_index','g_index','tori_index','riq_index']]

print "Total rows: ",len(numeric_components)
numeric_components=numeric_components.dropna()
print "Total rows cleaned from NaN values: ",len(numeric_components)
numeric_components['Figures']=numeric_components['Figures']*1.0/numeric_components['Pages']
numeric_components=numeric_components[numeric_components['Pub_cit_median']>5]
target=numeric_components['Citation_count']
print "Total rows filtered by Journal quality: ", len(numeric_components)
numeric_components.head()
# Out:
# Total rows:  6614
# Total rows cleaned from NaN values:  5832
# Total rows filtered by Journal quality:
#  4860
#     Figures  Pages  Year  Pub_cit_median  Avg_Cens    Avg_Cols    Avg_Pubs  \
# 0  1.333333      6  1993              27  0.000266  247.666667  113.333333
# 1  0.133333     15  1995              41  0.000430  129.250000   53.750000
# 2  0.095238     21  1995              43  0.000881   83.000000   31.000000
# 3  0.200000     15  1997              41  0.001094  185.000000   84.000000
# 4  0.153846     13  1995              41  0.002299  263.000000  174.333333
#
#    Max_Cens  Max_Cols  Max_Pubs    ...     Min_Pubs  author_counts  \
# 0  0.000383       294       169    ...           65              3
# 1  0.001164       208       118    ...            6              4
# 2  0.000881        83        31    ...           31              1
# 3  0.001094       185        84    ...           84              1
# 4  0.004546       424       242    ...           51              3
#
#    Citation_count  h_index  m_index  e_index  i10_index  g_index  tori_index  \
# 0              16        3      1.5      5.7          2        5         0.3
# 1              84        2      0.7     10.8          2        3         0.8
# 2              22       10      5.0     14.0         11       18         8.0
# 3              16        6      0.5     21.0          4       11        13.1
# 4              12        4      1.3     11.7          4        5         1.7
#
#    riq_index
# 0        293
# 1        303
# 2       1413
# 3        278
# 4        438
#
# [5 rows x 22 columns]

# %%
#Helper function to categorize classes based on the number of citations
def class_citations(element):
    if element<22:
        return 1
    elif element <55:
        return 2
    else:
        return 3
    
target_classes=np.array(map(class_citations,target))

for i in range(1,4):
    print "class"+str(i),list(target_classes).count(i)*1.0/len(target_classes)
# Out:
# class1 0.337037037037
# class2 0.329012345679
# class3 0.333950617284

# %%
#PC analysis
from sklearn.decomposition import PCA
params=['Figures','Pages','Year','Pub_cit_median','Avg_Cens','Avg_Cols','Avg_Pubs','Max_Cens','Max_Cols','Max_Pubs','Min_Cens','Min_Cols','Min_Pubs','author_counts','h_index','m_index','e_index','i10_index','g_index','tori_index','riq_index']


X_train, X_test, y_train, y_test = cross_validation.train_test_split(numeric_components[params], target_classes, test_size=0.2, random_state=0)


pca=PCA(n_components=10, copy=True, whiten=False)

X_new=pca.fit_transform(X_train)
plt.scatter(X_new[:,0],X_new[:,1],s=20, c=y_train)
plt.colorbar()
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.show()

# %%
#helper function to get all subsets
def powerset(iterable):
    s = list(iterable)
    return chain.from_iterable(combinations(s, r) for r in range(len(s)+1))

# %%
from sklearn import svm, grid_search

X_train, X_test, y_train, y_test = cross_validation.train_test_split(numeric_components[params], target_classes, test_size=0.25, random_state=0)

pca=PCA(n_components=10, copy=True, whiten=False)
X_train_new=pca.fit_transform(X_train)
X_test_new=pca.transform(X_test)

svr = svm.SVC()
clf = grid_search.GridSearchCV(svr,{'C':[1, 10, 100]})
clf.fit(X_train_new,y_train)


print "training data score ", clf.score(X_train_new,y_train)
print "test data score ", clf.score(X_test_new,y_test)
# Out:
# training data score
# 1.0
# test data score
# 0.332510288066

# %%
clf.get_params
# Out:
# <bound method GridSearchCV.get_params of GridSearchCV(cv=None,
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0, degree=3, gamma=0.0,
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False),
#        fit_params={}, iid=True, loss_func=None, n_jobs=1,
#        param_grid={'C': [1, 10, 100]}, pre_dispatch='2*n_jobs', refit=True,
#        score_func=None, scoring=None, verbose=0)>

# %%
X_train, X_test, y_train, y_test = cross_validation.train_test_split(numeric_components[params], target_classes, test_size=0.25, random_state=0)

svr = svm.SVC()
clf = grid_search.GridSearchCV(svr,{'C':[1, 10,100]})
clf.fit(X_train,y_train)
print "training data score ", clf.score(X_train,y_train)
print "test data score ", clf.score(X_test,y_test)
# Out:
# training data score
# 1.0
# test data score
# 0.334979423868

# %%
from sklearn.ensemble import GradientBoostingClassifier

X_train, X_test, y_train, y_test = cross_validation.train_test_split(numeric_components[params], target_classes, test_size=0.25,random_state=0)

GBC=GradientBoostingClassifier(loss='deviance', learning_rate=0.1, n_estimators=50, subsample=1.0, min_samples_split=2, min_samples_leaf=1, max_depth=3, init=None, random_state=None, max_features=None, verbose=0, max_leaf_nodes=None, warm_start=False)
scores = cross_validation.cross_val_score(GBC, X_train,y_train, cv=5)

print np.mean(scores)
clfgbc=GBC.fit(X_train,y_train)
print clfgbc.score(X_test,y_test)
# Out:
# 0.596171306285
# 0.612345679012

# %%
sorted_features1=sorted(zip(clfgbc.feature_importances_,params))
importances1,params_sorted1=zip(*sorted_features1)
plt.barh(range(len(params)),importances1,align='center')
plt.yticks(range(len(params)),params_sorted1);
plt.ylabel('feature');
plt.xlabel('importance');

# %%
from sklearn.ensemble import AdaBoostClassifier

X_train, X_test, y_train, y_test = cross_validation.train_test_split(numeric_components[params], target_classes, test_size=0.25, random_state=0)

ABC=AdaBoostClassifier(n_estimators=50)
scores = cross_validation.cross_val_score(ABC, X_train,y_train, cv=5)

print np.mean(scores)
clfabc=ABC.fit(X_train,y_train)
print clfabc.score(X_test,y_test)
# Out:
# 0.575869495144
# 0.58683127572

# %%
sorted_features2=sorted(zip(clfabc.feature_importances_,params))
importances2,params_sorted2=zip(*sorted_features2)
plt.barh(range(len(params)),importances2,align='center')
plt.yticks(range(len(params)),params_sorted2);
plt.ylabel('feature');
plt.xlabel('importance');

# %%
combined_score=[c+d for c,d in zip(clfgbc.feature_importances_,clfabc.feature_importances_)]
sorted_features3=sorted(zip(combined_score,params))
importances3,params_sorted3=zip(*sorted_features3)
p1=plt.barh(range(len(params)),importances1,align='center',color='b',label='GradientBoost')
p2=plt.barh(range(len(params)),importances2,align='center',color='r',left=importances1,label='Adaboost')
plt.yticks(range(len(params)),params_sorted3);
plt.ylabel('feature');
plt.xlabel('importance');
plt.legend(loc=4);

# %%
def most_common(lst):
    return max(set(lst), key=lst.count)

svmscore=[]
gbcscore=[]
abcscore=[]
combinedscore=[]

for i in range(50):
    X_train, X_test, y_train, y_test = cross_validation.train_test_split(numeric_components[params], target_classes, test_size=0.25)
    
    combined_predictions=pd.DataFrame(columns=['answer','SVM','GBC','ABC'])
    combined_predictions['answer']=y_test

    svr = svm.SVC()
    clf=svr.fit(X_train,y_train)
    combined_predictions['SVM']=map(clf.predict,X_test)
    svmscore.append(clf.score(X_test,y_test))
    
    GBC=GradientBoostingClassifier(loss='deviance', learning_rate=0.1, n_estimators=50, subsample=1.0, min_samples_split=2, min_samples_leaf=1, max_depth=3, init=None, random_state=None, max_features=None, verbose=0, max_leaf_nodes=None, warm_start=False)
    clfgbc=GBC.fit(X_train,y_train)
    combined_predictions['GBC']=map(clfgbc.predict,X_test)
    gbcscore.append(clfgbc.score(X_test,y_test))

    ABC=AdaBoostClassifier(n_estimators=50)
    clfabc=ABC.fit(X_train,y_train)
    
    combined_predictions['ABC']=map(clfabc.predict,X_test)
    abcscore.append(clfabc.score(X_test,y_test))


    combined_predictions['voted']=[[a[0],b[0],c[0]] for a,b,c in zip(combined_predictions['SVM'],combined_predictions['GBC'],combined_predictions['ABC'])]
    combined_predictions['predictions']=map(most_common,combined_predictions['voted'])
    
    
    combinedscore.append(len(combined_predictions[combined_predictions['answer']==combined_predictions['predictions']])*1.0/len(combined_predictions))

# %%
plt.plot(range(50),svmscore,label='svm')
plt.plot(range(50),gbcscore,label='gbc')
plt.plot(range(50),abcscore,label='abc')
plt.plot(range(50),combinedscore,label='combined')
plt.legend(loc=4)
plt.show()

# %%
top=0
for a,g,c in zip(abcscore,gbcscore,combinedscore):
    if c>g and c>a:
        top+=1
print top
# Out:
# 8
